# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv('../../scratch/netGW_KS/KS_netGW.csv')
df
# Out:
#       Unnamed: 0  year   KS_netGW    KS_pump
# 0              0  2016  24.919765  14.687940
# 1              1  2016  21.094305  11.028690
# 2              2  2016  23.716003  17.697200
# 3              3  2016  11.286495  23.596268
# 4              4  2016  42.655357  60.273075
# ...          ...   ...        ...        ...
# 7338        7338  2020  14.349680  50.164482
# 7339        7339  2020  27.762060  18.535225
# 7340        7340  2020  21.959854  15.132389
# 7341        7341  2020  13.133113  18.188580
# 7342        7342  2020  17.578966  13.088942
#
# [7343 rows x 4 columns]

# %%
r2 = r2_score(df.KS_pump, df.KS_netGW)
print('R2: ', r2)

rmse = mean_squared_error(y_true=df.KS_pump, y_pred=df.KS_netGW, squared=False)
print('RMSE: ', rmse)

fig, ax = plt.subplots()
ax.scatter(df.KS_pump, df.KS_netGW, alpha=0.3, marker='.')
ax.plot([0, 1], [0, 1], '-r', transform=ax.transAxes)
# Out:
# R2:  0.2673794558518917
# RMSE:  34.68276081319553
