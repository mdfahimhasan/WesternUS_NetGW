# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from plots_utils import make_scatter_line_plots, make_BOI_netGW_vs_pumping_vs_USGS_scatter_plot, \
                        make_line_plot_v1, make_line_plot_v2

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # model version = V9

# %% [markdown]
# # Annual pumping vs net GW (in m3) comparison for all basins

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')

# filtering steps for RPB, CO data; flow meters installed after 2010
ann_df = ann_df[~((ann_df['basin'] == 'Republican Basin, CO') & (ann_df['year'] < 2010))]

plot_save_path = './plots/all_basins_total_m3_comparison_v2.png'

basin_names = ('GMD4, KS', 'GMD3, KS', 'Republican Basin, CO', 'Harquahala INA, AZ', 'Douglas AMA, AZ', 'Diamond Valley, NV')

make_BOI_netGW_vs_pumping_vs_USGS_scatter_plot(df=ann_df, x1='sim_pumping_m3', y1='pumping_m3', hue='basin', 
                                               xlabel1='Simulated total pumping \n (m$^3$/year)', 
                                               ylabel1='Total pumping (m$^3$/year)', 
                                               fontsize=12, lim=(0, 4000000000),
                                               scientific_ticks=True, scilimits=(8, 8),
                                               basin_labels=basin_names,
                                               x2='USGS_m3', 
                                               y2='pumping_m3', 
                                               xlabel2='USGS-estimated total pumping \n (m$^3$/year)', 
                                               ylabel2='Total pumping (m$^3$/year)',
                                               figsize=(10, 6), savepath=plot_save_path)

# %%
basin_names = ('Harquahala INA, AZ', 'Douglas AMA, AZ', 'Diamond Valley, NV')
ann_df_sel = ann_df[ann_df['basin'].isin(basin_names)] 

plot_save_path = './plots/small_basins_total_m3_comparison_v2.png'

make_BOI_netGW_vs_pumping_vs_USGS_scatter_plot(df=ann_df_sel, x1='sim_pumping_m3', y1='pumping_m3', hue='basin', 
                                               xlabel1='Simulated total pumping \n (m$^3$/year)', 
                                               ylabel1='Total pumping (m$^3$/year)', 
                                               fontsize=12, lim=(0, 200000000),
                                               scientific_ticks=True, scilimits=(8, 8),
                                               basin_labels=basin_names,
                                               x2='USGS_m3', 
                                               y2='pumping_m3', 
                                               xlabel2='USGS-estimated total pumping \n (m$^3$/year)', 
                                               ylabel2='Total pumping (m$^3$/year)',
                                               figsize=(10, 6), savepath=plot_save_path)

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')

# filtering steps for RPB, CO data; flow meters installed after 2010
ann_df = ann_df[~((ann_df['basin'] == 'Republican Basin, CO') & (ann_df['year'] < 2010))]

plot_save_path = './plots/all_basins_mean_mm_comparison_v2.png'

basin_names = ('GMD4, KS', 'GMD3, KS', 'Republican Basin, CO', 'Harquahala INA, AZ', 'Douglas AMA, AZ', 'Diamond Valley, NV')

make_BOI_netGW_vs_pumping_vs_USGS_scatter_plot(df=ann_df, x1='sim_mean_pumping_mm', y1='mean pumping_mm', hue='basin', 
                                               xlabel1='Simulated mean pumping \n (mm/year)', 
                                               ylabel1='Mean pumping (mm/year)', 
                                               fontsize=12, lim=(0, 200),
                                               scientific_ticks=False, scilimits=(8, 8),
                                               basin_labels=basin_names,
                                               x2='mean USGS_mm', 
                                               y2='mean pumping_mm', 
                                               xlabel2='USGS-estimated mean pumping \n (mm/year)', 
                                               ylabel2='Mean pumping (mm/year)',
                                               figsize=(10, 6), savepath=plot_save_path)

# %% [markdown]
# ------------

# %% [markdown]
# # GMD4, Kansas

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'GMD4, KS']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annualpumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# -------------------

# %% [markdown]
# # GMD3, Kansas

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'GMD3, KS']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annualpumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# ---------

# %% [markdown]
# # RPB, Colorado

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'Republican Basin, CO']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annual pumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# ________________

# %% [markdown]
# # Harquahala INA, Arizona

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'Harquahala INA, AZ']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annual pumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# ------------------

# %% [markdown]
# # Douglas AMA, Arizona

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'Douglas AMA, AZ']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annual pumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# ----------

# %% [markdown]
# # Diamod Valley, Nevada

# %%
ann_df = pd.read_csv('../../Data_main/results_eval/netGW/annual_all_basins.csv')
ann_df_sel = ann_df[ann_df['basin'] == 'Diamond Valley, NV']
ann_df_sel.loc[ann_df_sel['mean pumping_mm'] < 1, 'mean pumping_mm'] = np.nan

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

make_line_plot_v2(y1=ann_df_sel['sim_mean_pumping_mm'], y2=ann_df_sel['mean pumping_mm'], y3=ann_df_sel['mean USGS_mm'], year=year, fontsize=12, 
                  xlabel_line='Year', ylabel_line='Mean annual pumping (mm/year)', 
                  line_label_1='Model estimated pumping', line_label_2='Actual pumping', line_label_3='USGS estimated pumping', 
                  figsize=(10, 4), legend_pos='upper left')

# %% [markdown]
# ----------------

# %% [markdown]
# # Harney Basin, OR

# %%
hrn_df = pd.read_csv('../../Data_main/Raster_data/NetGW_irrigation/Harney_Basin_OR/OR_Harney_Basin_annual.csv')
hrn_df
# Out:
#    year      netGW_AF    area_irrig   pumping_AF  mean netGW_mm  \
# 0  2016  24052.342688  6.692286e+13  9745.275173     443.318283
# 1  2017  29340.259515  8.153504e+13  8041.356017     443.866561
# 2  2018  29085.508999  8.035820e+13  9695.555198     446.456606
# 3  2019  28806.725194  8.705127e+13  8300.565889     408.179823
# 4  2020  29771.992434  8.213663e+13  8144.835966     447.099068
#
#    mean pumping_mm
# 0       785.809505
# 1       648.414117
# 2       781.800339
# 3       669.315485
# 4       656.758214

# %%
make_line_plot(x=hrn_df['mean netGW_mm'], y=hrn_df['mean pumping_mm'], 
               fontsize=12, year= hrn_df['year'], 
               xlabel_line='Year', ylabel_line='Mean annual water use (mm/year)', 
               line_label_1='Estimated net GW', line_label_2='Actual pumping')

# %% [markdown]
# -----------
