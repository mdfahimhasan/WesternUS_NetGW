# %%
import pandas as pd
from plots_utils import make_scatter_plot_irr_area

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## making irrigated area plots for basins in KS (GMD3 and GMD4) and CO (Republican Basin)
#
# `Couldn't find available in situ pumping acreage records for other basins.`

# %%
df = pd.read_csv('../../Data_main/results_eval/irr_acres/all_irr_acres.csv')
df.head()
# Out:
#    Year  In situ Acres  Irr data Acres    In situ m2   Irr data m2 basin_name
# 0  2000       387676.0       580340.20  1.568869e+09  2.348554e+09   GMD4, KS
# 1  2001       381380.0       549919.40  1.543390e+09  2.225445e+09   GMD4, KS
# 2  2002       387947.0       467589.80  1.569966e+09  1.892269e+09   GMD4, KS
# 3  2003       388110.0       544582.25  1.570625e+09  2.203846e+09   GMD4, KS
# 4  2004       386380.0       506482.60  1.563624e+09  2.049662e+09   GMD4, KS

# %%
plot_save_path = './plots/irr_acres_diff_all.png'

basin_names = ('GMD4, KS', 'GMD3, KS', 'Republican Basin, CO', 'Diamond Valley, NV')

make_scatter_plot_irr_area(df=df, x='Irr data m2', y='In situ m2', hue='basin_name',
                           fontsize=12, figsize=(5, 5), basin_labels=basin_names,
                           xlabel='Irrigated area from Irrigation dataset (m$^2$)', 
                           ylabel='Irrigated area from In situ records (m$^2$)', 
                           scientific_ticks=False, lim=(0, 9000000000),
                           savepath=plot_save_path)

# %%
basin_names = ('Diamond Valley, NV', ' ')
df_sel = df[df['basin_name'].isin(basin_names)] 

plot_save_path = './plots/irr_acres_diff_NV.png'

make_scatter_plot_irr_area(df=df_sel, x='Irr data m2', y='In situ m2', hue='basin_name',
                 fontsize=12, figsize=(5, 5), basin_labels=basin_names,
                 xlabel='Irrigated area from Irrigation \n dataset (m$^2$)', 
                 ylabel='Irrigated area from In situ \n records (m$^2$)', 
                 scientific_ticks=False, lim=(50000000, 150000000),
                 savepath=plot_save_path)
